# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# #### Load and Prepare Image

# %%
img = io.imread("lena.jpg")
img = np.array(img)

# %% [markdown]
# #### Convert RGB to grayscale using standard formula

# %%
def rgb2gray(rgb):
    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray.astype(np.uint8)

gray_img = rgb2gray(img)

# %% [markdown]
# ### Implement filter1() – basic convolution with offset (no edge handling yet)

# %% [markdown]
# If the filter is 3×3 → K = 1
#
# If the filter is 5×5 → K = 2
#
# If the filter is 7×7 → K = 3 <br><br>
#
# You don’t apply the filter on the border of the image (because there's no padding)
#
# K is how many pixels the filter extends above and below the center pixel
#
# So you remove K pixels from the top and bottom → 2*K total
#
# Example: for a 3×3 filter, K = 1 → you lose 1 pixel on each edge
#
# #### loop:
#
#  loop over every **valid center pixel** in the image.
# - start at `K` (e.g. `1` for a 3×3 filter) so the filter doesn’t go out of bounds.
# - go up to `height - K`, skipping pixels by `offset` (stride).
# - Same for `x`: move horizontally in steps of `offset`.
#
# >  This loop says:
# > “Slide the filter across the image, staying away from the edges, and move by `offset` pixels each step.”

# %%
def filter1(img, filt, offset):
    """
    Apply a linear filter with a given offset (stride) to a grayscale image.
    
    Parameters:
        img (2D np.array): input grayscale image
        filt (2D np.array): filter kernel (must be square NxN)
        offset (int): how many pixels to skip (stride)
        
    Returns:
        result (2D np.array): filtered output image
    """
    K = filt.shape[0] //2  #pixel from the center to the edge
    height, width = img.shape

    # output image is smaller because the filter needs to be centered on a pixel (can't be on edge pixles)
    out_height = (height - 2 * K) // offset
    out_width = (width - 2 * K) // offset
    result = np.zeros((out_height, out_width), dtype=np.uint8)

    # convolution
    for y in range(K, height - K, offset):
        for x in range(K, width - K, offset):
            # extract the local neighborhood
            region = img[y - K:y + K + 1, x - K:x + K + 1]
            # apply filter and clip the result to [0, 255]
            filtered_value = np.sum(region * filt)
            filtered_value = np.clip(filtered_value, 0, 255)
            result[(y - K) // offset, (x - K) // offset] = int(filtered_value)
    
    return result

# %% [markdown]
# #### Define filter masks

# %%
# 4-Neighbor Laplacian Filter (Edge detection: vertical + horizontal)
fm1 = np.array([
    [0,  1,  0],
    [1, -4,  1],
    [0,  1,  0]
])


# 8-Neighbor Laplacian Filter (Strong edge detection in all directions)
fm3 = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
])

# Box Blur Filter
fm4 = np.array([
    [1/9, 1/9, 1/9],
    [1/9, 1/9, 1/9],
    [1/9, 1/9, 1/9]
])

# Sharpening Filter
fm5 = np.array([
    [ 0, -1,  0],
    [-1,  5, -1],
    [ 0, -1,  0]
])

# Prewitt Operator
fm6 = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
])

# Sobel Operator
fm7 = np.array([
    [-1, 0, 1],
    [-2, 0, 2],
    [-1, 0, 1]
])

# Prewitt Operator
fm8 = np.array([
    [-1, -1, -1],
    [-2, 0, 2],
    [1, 1, 1]
])

fm9 = (1/16) * np.array([
    [1, 2, 1],
    [2, 4, 2],
    [1, 2, 1]
])

fm49 = (1/4096) * np.array([
    [1, 6, 15, 20, 15, 6, 1],
    [6, 36, 90, 120, 90, 36, 6],
    [15, 90, 225, 300, 225, 90, 15],
    [20, 120, 300, 400, 300, 120, 20],
    [15, 90, 225, 300, 225, 90, 15],
    [6, 36, 90, 120, 90, 36, 6],
    [1, 6, 15, 20, 15, 6, 1]
])

# %% [markdown]
# #### Apply filter1() and Show Result

# %%
#img5_out = filter1(gray_img, fm9, 1)
#img4_out = filter1(img5_out, fm9, 1)
#img3_out = filter1(img4_out, fm9, 1)
#img2_out = filter1(img3_out, fm9, 1)

img1_out = filter1(gray_img, fm6, 1)


plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.title("Original Grayscale Image")
plt.imshow(gray_img, cmap=cm.Greys_r)

plt.subplot(1, 2, 2)
plt.title("Filtered Image (Edge Detection)")
plt.imshow(img1_out, cmap=cm.Greys_r)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Second filter function:
# #### first lets define the functions that conrol the padding type.

# %% [markdown]
# #### Padding method 1: Zero padding (min)
#     Pads the image with zeros on all sides (zero padding).

# %%
def pad_min(img, k):
    return np.pad(img, pad_width=k, mode='constant', constant_values=0)

# %% [markdown]
# #### Padding method 2: Max value padding (255)
# Pads the image with 255 on all sides.

# %%
def pad_max(img, k):
    return np.pad(img, pad_width=k, mode='constant', constant_values=255)

# %% [markdown]
# #### Padding method 3: Edge replication (continue)
# Pads the image by repeating the edge values.

# %%
def pad_continue(img, k):
    return np.pad(img, pad_width=k, mode='edge')

# %% [markdown]
# #### filter2() now also handles edges based on the chosen padding type.

# %%
def filter2(img, filt, offset, edge):
    """
    Apply a linear filter with stride (offset) and edge handling.

    Parameters:
        img (2D np.array): input grayscale image
        filt (2D np.array): filter kernel (NxN, with N=2K+1)
        offset (int): stride (how many pixels to skip when sliding the filter)
        edge (str): padding method - 'min', 'max', or 'continue'

    Returns:
        result (2D np.array): filtered output image
    """
    K = filt.shape[0] // 2
    height, width = img.shape

    if edge == 'min':
        padded = pad_min(img, K)
    elif edge == 'max':
        padded = pad_max(img, K)
    elif edge == 'continue':
        padded = pad_continue(img, K)
    else:
        raise ValueError("Unknown edge type. Use 'min', 'max', or 'continue'.")

    # prepare output image
    out_height = (height - 0) // offset
    out_width = (width - 0) // offset
    result = np.zeros((out_height, out_width), dtype=np.uint8)

    # convolution
    for y in range(0, out_height * offset, offset):
        for x in range(0, out_width * offset, offset):
            # get region from padded image
            region = padded[y:y + 2 * K + 1, x:x + 2 * K + 1]
            # Apply filter
            filtered_value = np.sum(region * filt)
            # clip
            filtered_value = np.clip(filtered_value, 0, 255)
            # write to output
            result[y // offset, x // offset] = int(filtered_value)

    return result

# %% [markdown]
# #### show the filtered iage with filter2() that handles edges

# %%
img2_out = filter2(gray_img, fm6, 1, 'continue')

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(gray_img, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("Filtered Image with Edge = 'continue'")
plt.imshow(img2_out, cmap='gray')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### compare output of filter1 with output of filter2

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(img1_out, cmap='gray')
plt.title("filter1 (no padding)")

plt.subplot(1, 2, 2)
plt.imshow(img2_out, cmap='gray')
plt.title("filter2 (with padding)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Linear Filter
# A linear filter changes each pixel by taking a weighted sum of its neighboring pixels.<BR>
# It uses convolution and applies the same rule everywhere in the image.
#
# Examples: mean filter, Sobel filter, Laplace filter<BR>
# Properties: fast, simple, but sensitive to noise <br> <br>
# ### Non-linear filters
# A non-linear filter uses rules like sorting or choosing the median instead of averaging. <BR>
# It changes the pixel based on surrounding values, but not using simple mathematical operations.
#
# Examples: median filter, min/max filter <BR>
# Properties: good at removing noise, preserves edges better than linear filters

# %% [markdown]
# # Part 2: Non-linear filters:

# %% [markdown]
# #### implementing the median filter

# %%
tree = io.imread("tree.png")
tree = np.array(tree)

pepper = io.imread("pepper.jpg")
pepper = np.array(pepper)

# %%
import numpy as np
import heapq

def medianFilter(in_image, filtersize, offset):
    """
    Apply a median filter to a grayscale image using heap sort.
    
    Parameters:
        in_image (2D np.array): 8-bit grayscale image
        filtersize (int): size of the filter window (must be odd)
        offset (int): how many pixels to skip (stride)

    Returns:
        out_image (2D np.array): filtered image
    """
    assert filtersize % 2 == 1, "odd (3, 5, 7, ...)"
    
    K = filtersize // 2
    height, width = in_image.shape

    padded = np.pad(in_image, pad_width=K, mode='edge')

    out_height = (height) // offset
    out_width = (width) // offset
    out_image = np.zeros((out_height, out_width), dtype=np.uint8)

    for y in range(0, out_height * offset, offset):
        for x in range(0, out_width * offset, offset):
            # Extract the window
            window = padded[y:y + filtersize, x:x + filtersize].flatten()

            # heap sort (convert list to heap and pop until median)
            window_list = list(window)
            heapq.heapify(window_list)
            sorted_window = sorted(window)  # Not real heap sort, but fast + simple
            
            # het median
            mid = len(sorted_window) // 2
            median_val = sorted_window[mid]

            out_image[y // offset, x // offset] = median_val

    return out_image

# %%
filtered = medianFilter(tree, 3, 1)

# Show the result
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(tree, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("After Median Filter")
plt.imshow(filtered, cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### a) Compare the results of different filters and explain them.
# Mean filter (linear): Blurs the image and removes noise but also blurs edges.
#
# Median filter (non-linear): Removes salt and pepper noise very well and preserves edges better.
#
# Laplacian filter (edge detection): Highlights edges but does not remove noise.

# %% [markdown]
# #### b) Why is Heap Sort useful for the median filter?
# Heap Sort is efficient for finding the median.
#
# It’s good when you don’t need the full sorted list, just the middle value.
#
# It's also memory-efficient and handles small, repeated windows well.

# %% [markdown]
# #### c) What happens when a filter is applied multiple times?
# Median filter: Removes more noise with each pass but can start blurring fine details.
#
# Mean filter: Gets more blurry the more times it is applied.
#
# Edge filters (like Laplacian): Repeated use may produce high contrast noise or halos.
#
# ->More filtering = smoother image but less detail.

# %% [markdown]
# #### d) What effects occur with large and small filter masks?
# ##### Small filter mask (e.g. 3×3):
#
# Less smoothing, better detail
#
# ##### Large filter mask (e.g. 7×7):
#
# More smoothing, less detail, good for heavy noise, but may blur important features

# %% [markdown]
# ### Min filter (just testing)

# %%
import numpy as np

def minimumFilter(in_image, filtersize, offset):
    """
    Apply a minimum filter to a grayscale image.
    
    Parameters:
        in_image (2D np.array): 8-bit grayscale image
        filtersize (int): Size of the filter window (must be odd)
        offset (int): Stride (how many pixels to skip)
    
    Returns:
        out_image (2D np.array): Filtered output image
    """
    assert filtersize % 2 == 1, "Filter size must be odd (3, 5, 7, ...)"

    K = filtersize // 2
    height, width = in_image.shape

    padded = np.pad(in_image, pad_width=K, mode='edge')

    out_height = (height) // offset
    out_width = (width) // offset
    out_image = np.zeros((out_height, out_width), dtype=np.uint8)

    for y in range(0, out_height * offset, offset):
        for x in range(0, out_width * offset, offset):
            # Extract the local window
            window = padded[y:y + filtersize, x:x + filtersize].flatten()
            
            # Find the minimum value in the window
            min_val = np.max(window)

            # Save the minimum value to the output
            out_image[y // offset, x // offset] = min_val

    return out_image

# %%
import matplotlib.pyplot as plt
from skimage import io

img = io.imread('pepper.jpg')  
if img.ndim == 3:
    from skimage.color import rgb2gray
    img = (rgb2gray(img) * 255).astype(np.uint8)

filtered = minimumFilter(img, filtersize=3, offset=1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(img, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("After Minimum Filter")
plt.imshow(filtered, cmap='gray')

plt.tight_layout()
plt.show()
